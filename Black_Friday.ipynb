# %% [markdown]
# <a href="https://colab.research.google.com/github/Divyaraj-M/Divyaraj-M/blob/main/Black_Friday.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/train.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
del df['Product_Category_2']
del df['Product_Category_3']
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Purchase                      0
# dtype: int64

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
df['Product_ID']
# Out:
# 0         P00069042
# 1         P00248942
# 2         P00087842
# 3         P00085442
# 4         P00285442
#             ...
# 550063    P00372445
# 550064    P00375436
# 550065    P00375436
# 550066    P00375436
# 550067    P00371644
# Name: Product_ID, Length: 550068, dtype: object

# %%
df['User_ID'].nunique()
# Out:
# 5891

# %%
df['User_ID'].unique()
# Out:
# array([1000001, 1000002, 1000003, ..., 1004113, 1005391, 1001529])

# %%
    df['Occupation'].unique()
# Out:
# array([10, 16, 15,  7, 20,  9,  1, 12, 17,  0,  3,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6])

# %%
for column in df.columns:
    print(column, ':',df[column].nunique())
# Out:
# User_ID : 5891
# Product_ID : 3631
# Gender : 2
# Age : 7
# Occupation : 21
# City_Category : 3
# Stay_In_Current_City_Years : 5
# Marital_Status : 2
# Product_Category_1 : 20
# Purchase : 18105

# %%
#Analysing Gender with purchases

# %%
len(df[df['Gender']=='M'])
# Out:
# 414259

# %%
len(df[df['Gender']=='F'])
# Out:
# 135809

# %%
data = {'Ratio': [len(df[df['Gender'] == 'M']), len(df[df['Gender'] == 'F'])]}
df_result = pd.DataFrame(data, index=['Male', 'Female'])

# %%
df_result.plot.pie(y='Ratio',figsize = (6,5),autopct = "%.1f")
# Out:
# <Axes: ylabel='Ratio'>

# %%
df.groupby('Gender').size().plot(kind='pie',autopct='%.0f',title='Gender Ratio',figsize=(4,4))
# Out:
# <Axes: title={'center': 'Gender Ratio'}>

# %%
df.groupby('Gender').size().plot(kind='bar',title='Gender Ratio',figsize=(4,4))
# Out:
# <Axes: title={'center': 'Gender Ratio'}, xlabel='Gender'>

# %%
df.groupby('Gender')['Purchase'].mean().plot(kind ='pie',autopct = '%.1f')
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby('Gender')['Purchase'].sum().plot(kind='pie', autopct='%.1f')
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby('Age').size().plot(kind='line',figsize=(12,6),title="Purchase distribution by Age")
# Out:
# <Axes: title={'center': 'Purchase distribution by Age'}, xlabel='Age'>

# %%
for i in df['Age'].unique():
    print(i,':', df[df['Age']==i]['Product_ID'].nunique())
# Out:
# 0-17 : 2323
# 55+ : 2584
# 26-35 : 3427
# 46-50 : 3106
# 51-55 : 2887
# 36-45 : 3328
# 18-25 : 3220

# %%
df[df['Age']== i]['Product_ID'].nunique()
# Out:
# 3220

# %%
lst =[]
for i in df['Age'].unique():
    lst.append([i,df[df['Age']== i]['Product_ID'].nunique()])
data = pd.DataFrame(lst,columns=['Age','Products'])

# %%
data.plot.bar(x='Age', figsize=(8,6))
# Out:
# <Axes: xlabel='Age'>

# %%
data
# Out:
#      Age  Products
# 0   0-17      2323
# 1    55+      2584
# 2  26-35      3427
# 3  46-50      3106
# 4  51-55      2887
# 5  36-45      3328
# 6  18-25      3220

# %%
df.groupby('Age')['Purchase'].sum().plot(kind='line',figsize=(12,6),title="AMount spend by Age")
# Out:
# <Axes: title={'center': 'AMount spend by Age'}, xlabel='Age'>
